# %%
import pandas as pd
import random

# %% [markdown]
# ## Generate and Insert Data into Database - Facebook Users - Generate 6 000 000 records

# %%
import random
import string
import mysql.connector  # Replace with your database connector library (e.g., psycopg2 for PostgreSQL)

# Database connection details (replace with your credentials)
DB_HOST = "localhost"
DB_USER = "root"
DB_PASSWORD = "visal"
DB_NAME = "user"

# Function to generate random data (you can customize this)
def generate_data():
    countries = [
        "Australia", "Brunei", 
        "Cambodia", "Canada", 
        "Vietnam", "France", 
        "Germany", "India", 
        "Indonesia", "Italy", 
        "Japan", "Laos", 
        "Malaysia", "Myanmar", 
        "Norway", "Singapore",
        "Spain", "Thailand", 
        "United Kingdom", "United States"
    ]
    name = ''.join(random.choice(string.ascii_uppercase + string.digits) for _ in range(10))
    email = f"{name.lower()}@{random.randint(1, 100)}.com"
    age = random.randint(18, 65)
    country = random.choice(countries)
    return name, email, age, country

# Connect to the database
try:
    connection = mysql.connector.connect(host=DB_HOST, user=DB_USER, password=DB_PASSWORD, database=DB_NAME)
    cursor = connection.cursor()
except mysql.connector.Error as err:
    print("Error connecting to database:", err)
    exit()

# Create table if it doesn't exist (replace with your table schema)
create_table_query = """
CREATE TABLE IF NOT EXISTS facebook_users (
id INT AUTO_INCREMENT PRIMARY KEY,
name VARCHAR(255) NOT NULL,
email VARCHAR(255) NOT NULL UNIQUE,
age INT NOT NULL,
country VARCHAR(255) NOT NULL
)
"""
cursor.execute(create_table_query)
connection.commit()

# Generate and insert data
print('Start inserting ...')
insertion_amount = 100
num_records = 60000
i = 0
for k in range(insertion_amount):
    for _ in range(num_records):
        name, email, age, country = generate_data()
        insert_query = """
        INSERT INTO facebook_users (name, email, age, country)
        VALUES (%s, %s, %s, %s)
        """
        cursor.execute(insert_query, (name, email, age, country))
    connection.commit()
    i = i + 1
    print('Insertion round', i, num_records, 'records.')

print(f"Successfully inserted {num_records*insertion_amount} records into the database.")

# Close the connection
cursor.close()
connection.close()

print('Finished inserting!!!')
# Out:
# Start inserting ...
# Insertion round 1 60000 records.
# Insertion round 2 60000 records.
# Insertion round 3 60000 records.
# Insertion round 4 60000 records.
# Insertion round 5 60000 records.
# Insertion round 6 60000 records.
# Insertion round 7 60000 records.
# Insertion round 8 60000 records.
# Insertion round 9 60000 records.
# Insertion round 10 60000 records.
# Insertion round 11 60000 records.
# Insertion round 12 60000 records.
# Insertion round 13 60000 records.
# Insertion round 14 60000 records.
# Insertion round 15 60000 records.
# Insertion round 16 60000 records.
# Insertion round 17 60000 records.
# Insertion round 18 60000 records.
# Insertion round 19 60000 records.
# Insertion round 20 60000 records.
# Insertion round 21 60000 records.
# Insertion round 22 60000 records.
# Insertion round 23 60000 records.
# Insertion round 24 60000 records.
# Insertion round 25 60000 records.
# Insertion round 26 60000 records.
# Insertion round 27 60000 records.
# Insertion round 28 60000 records.
# Insertion round 29 60000 records.
# Insertion round 30 60000 records.
# Insertion round 31 60000 records.
# Insertion round 32 60000 records.
# Insertion round 33 60000 records.
# Insertion round 34 60000 records.
# Insertion round 35 60000 records.
# Insertion round 36 60000 records.
# Insertion round 37 60000 records.
# Insertion round 38 60000 records.
# Insertion round 39 60000 records.
# Insertion round 40 60000 records.
# Insertion round 41 60000 records.
# Insertion round 42 60000 records.
# Insertion round 43 60000 records.
# Insertion round 44 60000 records.
# Insertion round 45 60000 records.
# Insertion round 46 60000 records.
# Insertion round 47 60000 records.
# Insertion round 48 60000 records.
# Insertion round 49 60000 records.
# Insertion round 50 60000 records.
# Insertion round 51 60000 records.
# Insertion round 52 60000 records.
# Insertion round 53 60000 records.
# Insertion round 54 60000 records.
# Insertion round 55 60000 records.
# Insertion round 56 60000 records.
# Insertion round 57 60000 records.
# Insertion round 58 60000 records.
# Insertion round 59 60000 records.
# Insertion round 60 60000 records.
# Insertion round 61 60000 records.
# Insertion round 62 60000 records.
# Insertion round 63 60000 records.
# Insertion round 64 60000 records.
# Insertion round 65 60000 records.
# Insertion round 66 60000 records.
# Insertion round 67 60000 records.
# Insertion round 68 60000 records.
# Insertion round 69 60000 records.
# Insertion round 70 60000 records.
# Insertion round 71 60000 records.
# Insertion round 72 60000 records.
# Insertion round 73 60000 records.
# Insertion round 74 60000 records.
# Insertion round 75 60000 records.
# Insertion round 76 60000 records.
# Insertion round 77 60000 records.
# Insertion round 78 60000 records.
# Insertion round 79 60000 records.
# Insertion round 80 60000 records.
# Insertion round 81 60000 records.
# Insertion round 82 60000 records.
# Insertion round 83 60000 records.
# Insertion round 84 60000 records.
# Insertion round 85 60000 records.
# Insertion round 86 60000 records.
# Insertion round 87 60000 records.
# Insertion round 88 60000 records.
# Insertion round 89 60000 records.
# Insertion round 90 60000 records.
# Insertion round 91 60000 records.
# Insertion round 92 60000 records.
# Insertion round 93 60000 records.
# Insertion round 94 60000 records.
# Insertion round 95 60000 records.
# Insertion round 96 60000 records.
# Insertion round 97 60000 records.
# Insertion round 98 60000 records.
# Insertion round 99 60000 records.
# Insertion round 100 60000 records.
# Successfully inserted 6000000 records into the database.
# Finished inserting!!!

# %% [markdown]
# ## Sample Data Users

# %%
# import random
# import string
# import mysql.connector  # Replace with your database connector library (e.g., psycopg2 for PostgreSQL)

# # Database connection details (replace with your credentials)
# DB_HOST = "localhost"
# DB_USER = "root"
# DB_PASSWORD = ""
# DB_NAME = "big_data_db"

# # Function to generate random data (you can customize this)
# def generate_data():
#     name = ''.join(random.choice(string.ascii_uppercase + string.digits) for _ in range(10))
#     email = f"{name.lower()}@{random.randint(1, 100)}.com"
#     age = random.randint(18, 65)
#     return name, email, age

# # Connect to the database
# try:
#     connection = mysql.connector.connect(host=DB_HOST, user=DB_USER, password=DB_PASSWORD, database=DB_NAME)
#     cursor = connection.cursor()
# except mysql.connector.Error as err:
#     print("Error connecting to database:", err)
#     exit()

# # Create table if it doesn't exist (replace with your table schema)
# create_table_query = """
# CREATE TABLE IF NOT EXISTS users (
#   id INT AUTO_INCREMENT PRIMARY KEY,
#   name VARCHAR(255) NOT NULL,
#   email VARCHAR(255) NOT NULL UNIQUE,
#   age INT NOT NULL
# )
# """
# cursor.execute(create_table_query)
# connection.commit()

# # Generate and insert data
# print('Start inserting ...')
# insertion_amount = 100
# num_records = 100000
# i = 0
# for k in range(insertion_amount):
#     for _ in range(num_records):
#         name, email, age = generate_data()
#         insert_query = """
#         INSERT INTO users (name, email, age)
#         VALUES (%s, %s, %s)
#         """
#         cursor.execute(insert_query, (name, email, age))
#     connection.commit()
#     i = i + 1
#     print('Insertion round', i, num_records, 'records.')

# print(f"Successfully inserted {num_records*insertion_amount} records into the database.")

# # Close the connection
# cursor.close()
# connection.close()

# print('Finished inserting!!!')
